# %%
import pandas as pd

df = pd.read_csv('C:\Users\zebronics\Downloads\unsupervised learning\StudentsPerformance.csv')
print(df.head())
print(df.isnull().sum())
# Out:
#   Cell In[1], line 3
#     df = pd.read_csv('C:\Users\zebronics\Downloads\unsupervised learning\StudentsPerformance.csv')
#                                                                                                  ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape
